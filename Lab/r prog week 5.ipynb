# %%
x <- NA
x

is.na(x)
# Out:
# [1] NA
# [1] TRUE

# %%
x <- c(11, NA, 13, NA)

x

is.na(x)
# Out:
# [1] 11 NA 13 NA
# [1] FALSE  TRUE FALSE  TRUE

# %%
x <- c(11, NA, 13, NA)

mean(x)

mean(x, na.rm = TRUE)
# Out:
# [1] NA
# [1] 12

# %%
x <- c(11, NA, 13, NA)

x

which(is.na(x))
# Out:
# [1] 11 NA 13 NA
# [1] 2 4

# %%
x <- c(11, NA, 13, NA)

x

sum(is.na(x))
# Out:
# [1] 11 NA 13 NA
# [1] 2

# %%
x <- c(11, NA, 13, NA)

x

complete.cases(x)
# Out:
# [1] 11 NA 13 NA
# [1]  TRUE FALSE  TRUE FALSE

# %%
x <- c(11, NA, 13, NA)

x

y <- na.omit(x)

y
# Out:
# [1] 11 NA 13 NA
# [1] 11 13
# attr(,"na.action")
# [1] 2 4
# attr(,"class")
# [1] "omit"

# %%
x <- c(11, NA, 13, NA)

y <- na.omit(x)

mean(x)

mean(y)
# Out:
# [1] NA
# [1] 12

# %%
x <- 5

if (x > 4)
    x * 3
# Out:
# [1] 15

# %%
x <- 5

if (x > 4) {
    x * 3
}
# Out:
# [1] 15

# %%
x <- 6

if (x > 3) {
    print("The value is more than 3")
}
# Out:
# [1] "The value is more than 3"

# %%
x <- 2

if (x > 3) {
    print("The value is more than 3")
}

# %%
x <- 6

if (x > 3) {
    print("The value is more than 3")
} else {
    print("The value is less than or equal to 3")
}
# Out:
# [1] "The value is more than 3"

# %%
x <- 2

if (x > 3) {
    print("The value is more than 3")
} else {
    print("The value is less than or equal to 3")
}
# Out:
# [1] "The value is less than or equal to 3"

# %%
x <- 10

if (x > 10) {
    print("Greater than 10")
} else if (x == 10) {
    print("Equal to 10")
} else {
    print("Less than 10")
}
# Out:
# [1] "Equal to 10"

# %%
x <- c(12, NA, 25, 18, NA, 40)

is.na(x)

which(is.na(x))

sum(is.na(x))

complete.cases(x)

na.omit(x)

mean(x, na.rm = TRUE)
# Out:
# [1] FALSE  TRUE FALSE FALSE  TRUE FALSE
# [1] 2 5
# [1] 2
# [1]  TRUE FALSE  TRUE  TRUE FALSE  TRUE
# [1] 12 25 18 40
# attr(,"na.action")
# [1] 2 5
# attr(,"class")
# [1] "omit"
# [1] 23.75

# %%
x <- 15

if (x %% 2 == 0) {
    print("Even")
} else {
    print("Odd")
}
# Out:
# [1] "Odd"

# %%
marks <- 82

if (marks >= 90) {
    print("Grade A")
} else if (marks >= 75) {
    print("Grade B")
} else if (marks >= 60) {
    print("Grade C")
} else {
    print("Fail")
}
# Out:
# [1] "Grade B"

# %%
num <- -5

if (num > 0) {
    print("Positive")
} else if (num < 0) {
    print("Negative")
} else {
    print("Zero")
}
# Out:
# [1] "Negative"
